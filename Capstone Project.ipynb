# %% [markdown]
# This notebook will be mainly for the Data Science Capstone prject, Battle of The Neighbourhoods were we will be looking at cities such as Toronto and New York, to determine the differences and similarities between them.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
